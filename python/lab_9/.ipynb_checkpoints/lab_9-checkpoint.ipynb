# %%
# %load_ext autoreload
# %autoreload 2

from ble import get_ble_controller
from base_ble import LOG
from cmd_types import CMD
import time
import numpy as np
import math
import csv
import re

import matplotlib as mpl
import matplotlib.pyplot as plt

from scipy import pi
from scipy.fftpack import fft

LOG.propagate = False

# %%
# Get ArtemisBLEController object
ble = get_ble_controller()

# Connect to the Artemis Device
ble.connect()

CURR_LOG_ARRAY = None
log_complete = False

def ble_msg_handler(sender, msg):
    msg = msg.decode("utf-8")
    end_regex = r'<END BUFFER [a-z, A-Z]*>'
    if re.search(end_regex, msg) != None:
        print("Buffer read complete.")
        log_complete = True
    msg_regex = r'[A-Za-z]*: -?(\d*.?(?:\d*)?)' # Match Data of the form "[name]: [data]"
    data = re.findall(msg_regex, msg)
    if data == None:
        return
    if len(data) == 0:
        return
    CURR_LOG_ARRAY.append(data)
# Out:
# 2023-04-12 16:18:32,786 | INFO     |: Looking for Artemis Nano Peripheral Device: c0:83:0c:66:2f:3c
# 2023-04-12 16:18:35,902 | INFO     |: Connected to c0:83:0c:66:2f:3c

# %%
ble.send_command(CMD.DISABLE_ROBOT, "")

# %%
ble.send_command(CMD.ENABLE_ROBOT, "")

# %%
ble.send_command(CMD.SET_PID_GAINS,"ROTATION:|0.015:|0.002:|0.0")

# %%
print("starting reading")
tof = []
pose = []
motor = []
ble.send_command(CMD.ENABLE_BUFFER, "POSE")
ble.send_command(CMD.ENABLE_BUFFER, "TOF")
ble.send_command(CMD.ENABLE_BUFFER, "MOTOR")
ble.send_command(CMD.SET_PID_GAINS,"ROTATION:|-0.01:|-0.001:|0.0")
ble.send_command(CMD.ENABLE_ROBOT, "")
time.sleep(35)                                                                                                                 
ble.send_command(CMD.DISABLE_ROBOT, "")
ble.send_command(CMD.DISABLE_BUFFER, "POSE")
ble.send_command(CMD.DISABLE_BUFFER, "TOF")
ble.send_command(CMD.DISABLE_BUFFER, "MOTOR")
ble.start_notify(ble.uuid['RX_STRING'], ble_msg_handler)
print("reading complete")
# Out:
# starting reading
# reading complete

# %%
CURR_LOG_ARRAY = tof
ble.send_command(CMD.RETRIEVE_BUFFER, "TOF")
print("Waiting for buffer to fill...")
# Out:
# Waiting for buffer to fill...
# Buffer read complete.

# %%
tof = np.array(tof).astype(float)
#tof = np.load("tof_lab_6.npy")
plt.plot(tof[:, 0], tof[:, 1])
plt.plot(tof[:, 0], tof[:, 2])
plt.xlabel("Time (ms)")
plt.ylabel("Distance (mm)")
plt.title("TOF Distance Readings vs Time")
plt.legend(["Sensor A", "Sensor B"])
plt.show()
plt.savefig('tof_time_3.png')
#np.save("new_tof_lab_7", tof)

# %%
CURR_LOG_ARRAY = pose
ble.send_command(CMD.RETRIEVE_BUFFER, "POSE")
print("Waiting for buffer to fill...")
# Out:
# Waiting for buffer to fill...
# Buffer read complete.

# %%
pose = np.array(pose).astype(float)
#pose = np.load("pose_lab_6.npy")
plt.plot(pose[:, 0], pose[:, 3])
plt.xlabel("Time (ms)")
plt.ylabel("Angle (deg)")
plt.title("Rotational Pose vs Time")
plt.legend(["Z"])
plt.show()
delta = pose[1:pose.shape[0]] - pose[0:-1, :]
plt.plot(pose[0:-1, 0], (delta[:, 3] / delta[:, 0]) * 1000)
plt.xlabel("Time (ms)")
plt.ylabel("Angle (deg)")
plt.title("Rotational Pose vs Time")
plt.ylim([-10,50])
plt.legend(["Z"])
plt.show()
#np.save("new_pose_lab_7", pose)

# %%
CURR_LOG_ARRAY = motor
ble.send_command(CMD.RETRIEVE_BUFFER, "MOTOR")
print("Waiting for buffer to fill...")
# Out:
# Waiting for buffer to fill...
# Buffer read complete.

# %%
motor = np.array(motor).astype(float)
#motor = np.load("motor_lab_6.npy")
plt.plot(motor[:, 0], motor[:, 1])
plt.plot(motor[:, 0], motor[:, 2])
plt.xlabel("Time (ms)")
plt.ylabel("Output")
plt.title("Motor Output vs Time")
plt.legend(["Left", "Right"])
plt.show()

plt.savefig('motor_time_3.png')
#np.save("new_motor_lab_7", motor)

# %%
suff = "_(0,0)"


np.save("lab_9/lab_9_pose"+suff, pose)

np.save("lab_9/lab_9_tof"+suff, tof)

np.save("lab_9/lab_9_motor"+suff, motor)

# %%
test = np.load("lab_9/lab_9_tof_(-3,-2).npy")

# %%
# Out:
# [[20738.      699.      699.      699.   ]
#  [20929.      705.      697.      699.72 ]
#  [21116.      701.      696.      698.719]
#  [21306.      703.      698.      699.971]
#  [21495.      708.      694.      701.299]
#  [21678.      716.      692.      704.335]
#  [21864.      721.      683.      703.26 ]
#  [22044.      735.      680.      707.688]
#  [22236.      760.      675.      717.97 ]
#  [22425.      772.      671.      722.88 ]
#  [22612.      784.      670.      728.57 ]
#  [22792.      810.      670.      740.342]
#  [22977.      835.      665.      750.946]
#  [23171.      868.      671.      769.124]
#  [23364.      887.      669.      779.549]
#  [23546.      905.      671.      789.581]
#  [23727.      937.      676.      806.734]
#  [23919.      952.      676.      816.207]
#  [24098.      966.      681.      825.153]
#  [24294.      963.      682.      825.548]
#  [24481.      957.      693.      827.956]
#  [24666.      938.      703.      824.122]
#  [24847.      920.      711.      818.977]
#  [25033.      885.      718.      805.823]
#  [25217.      860.      736.      801.136]
#  [25413.      825.      752.      791.367]
#  [25600.      799.      764.      783.994]
#  [25781.      781.      782.      783.51 ]
#  [25964.      774.      795.      785.452]
#  [26155.      759.      813.      787.69 ]
#  [26350.      751.      839.      796.3  ]
#  [26522.      751.      857.      804.943]
#  [26716.      732.      890.      812.504]
#  [26897.      719.      928.      823.969]
#  [27095.      714.      948.      832.901]
#  [27278.      711.      964.      839.293]
#  [27455.      702.      977.      841.583]
#  [27646.      699.      971.      838.302]
#  [27829.      703.      943.      827.276]
#  [28015.      702.      919.      814.394]
#  [28204.      706.      878.      796.751]
#  [28395.      709.      842.      779.418]
#  [28579.      714.      815.      766.964]
#  [28764.      717.      789.      755.849]
#  [28948.      725.      781.      754.239]
#  [29135.      728.      767.      748.773]
#  [29328.      737.      750.      744.827]
#  [29519.      743.      738.      741.683]
#  [29695.      755.      726.      741.174]
#  [29891.      759.      721.      741.267]
#  [30069.      772.      707.      740.579]
#  [30266.      782.      697.      740.62 ]
#  [30449.      798.      689.      744.105]
#  [30635.      817.      691.      754.254]
#  [30823.      829.      682.      756.75 ]
#  [31003.      854.      676.      765.809]
#  [31195.      876.      674.      775.919]
#  [31389.      906.      680.      793.197]
#  [31568.      937.      676.      806.906]
#  [31762.      943.      685.      816.13 ]
#  [31941.      947.      696.      822.992]
#  [32129.      938.      698.      821.815]
#  [32313.      922.      711.      819.498]
#  [32498.      878.      720.      804.712]
#  [32695.      853.      716.      788.91 ]
#  [32878.      833.      734.      785.461]
